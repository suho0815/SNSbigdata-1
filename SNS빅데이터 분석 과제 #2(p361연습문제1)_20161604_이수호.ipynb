# %%
from bs4 import BeautifulSoup
from selenium import webdriver

import time
import sys
import re
import math
import numpy 
import pandas as pd   
import xlwt 
import random
import os
import urllib.request

print("=" *70)
print("    아마존 닷컴의 분야별 Best Seller 상품 정보 추출하기 + 이미지 포함")
print("=" *70)
print("\n")

title='아마존닷컴'
url='https://www.amazon.com/bestsellers?ld=NSGoogle'

sec = input('''
    1.Amazon Devices & Accessories      2.Amazon Launchpad                3.Appliances
    4.Apps & Games                      5.Arts, Crafts & Sewing           6.Audible Books & Originals
    7.Automotive                        8.Baby                            9.Beauty & Personal Care
    10.Books                            11.CDs & Vinyl                    12.Camera & Photo Products
    13.Cell Phones & Accessories        14.Clothing, Shoes & Jewelry      15.Collectible Currencies
    16.Computers & Accessories          17.Digital Educational Resources  18.Digital Music
    19.Electronics                      20.Entertainment Collectibles     21.Gift Cards 
    22.Grocery & Gourmet Food           23.Handmade Products              24.Health & Household
    25.Home & Kitchen                   26.Industrial & Scientific        27.Kindle Store
    28.Kitchen & Dining                 29.Magazine Subscriptions         30.Movies & TV        
    31.Musical Instruments              32.Office Products                33.Patio, Lawn & Garden               
    34.Pet Supplies                     35.Software                       36.Sports & Outdoors                   
    37.Sports Collectibles              38.Tools & Home Improvement       39.Toys & Games  
    40.Video Games

    1.위 분야 중에서 자료를 수집할 분야의 번호를  선택하세요: ''')

cnt = int(input('    2.해당 분야에서 크롤링 할 건수는 몇건입니까?(1-100 건 사이 입력): '))

f_dir = input("    3.파일을 저장할 폴더명만 쓰세요(예:C:\py_temp\):")
print("\n")

if sec == '1' :
      sec_name='Amazon Devices and Accessories'
elif sec =='2' :
      sec_name='Amazon Launchpad'
elif sec =='3' :
      sec_name='Appliances'
elif sec =='4' :
      sec_name='Apps and Games'
elif sec =='5' :
      sec_name='Arts and Crafts and Sewing'
elif sec =='6' :
      sec_name='Audible Books & Originals'        
elif sec =='7' :
      sec_name='Automotive'        
elif sec =='8' :
      sec_name='Baby'
elif sec =='9' :
      sec_name='Beauty & Personal Care'
elif sec =='10' :
      sec_name='Books'
elif sec =='11' :
      sec_name='CDs & Vinyl'
elif sec =='12' :
      sec_name='Camera & Photo Products'
elif sec =='13' :
      sec_name='Cell Phones & Accessories'
elif sec =='14' :
      sec_name='Clothing, Shoes & Jewelry'
elif sec =='15' :
      sec_name='Collectible Currencies'
elif sec =='16' :
      sec_name='Computers & Accessories'
elif sec =='17' :
      sec_name='Digital Educational Resources'
elif sec =='18' :
      sec_name='Digital Music'
elif sec =='19' :
      sec_name='Electronics'
elif sec =='20' :
      sec_name='Entertainment Collectibles'
elif sec =='21' :
      sec_name='Gift Cards'
elif sec =='22' :
      sec_name='Grocery & Gourmet Food'
elif sec =='23' :
      sec_name='Handmade Products'
elif sec =='24' :
      sec_name='Health & Household'
elif sec =='25' :
      sec_name='Home & Kitchen'
elif sec =='26' :
      sec_name='Industrial & Scientific'
elif sec =='27' :
      sec_name='Kindle Store'
elif sec =='28' :
      sec_name='Kitchen & Dining'
elif sec =='29' :
      sec_name='Magazine Subscriptions'
elif sec =='30' :
      sec_name='Movies & TV'
elif sec =='31' :
      sec_name='Musical Instruments'
elif sec =='32' :
      sec_name='Office Products'
elif sec =='33' :
      sec_name='Patio, Lawn & Garden'
elif sec =='34' :
      sec_name='Pet Supplies'
elif sec =='35' :
      sec_name='Software'
elif sec =='36' :
      sec_name='Sports & Outdoors'
elif sec =='37' :
      sec_name='Sports Collectibles'
elif sec =='38' :
      sec_name='Tools & Home Improvement'
elif sec =='39' :
      sec_name='Toys & Games'
elif sec =='40' :
      sec_name='Video Games'

        
print(sec_name)
print("데이터 수집 중~~")


#파일 이름 지정
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

os.makedirs(f_dir+s+'-'+title+'-'+sec_name)
os.chdir(f_dir+s+'-'+title+'-'+sec_name)

ft_dir=f_dir+s+'-'+title+'-'+sec_name
ft_name=f_dir+s+'-'+title+'-'+sec_name+'\\'+s+'-'+title+'-'+sec_name+'.txt'
fc_name=f_dir+s+'-'+title+'-'+sec_name+'\\'+s+'-'+title+'-'+sec_name+'.csv'
fx_name=f_dir+s+'-'+title+'-'+sec_name+'\\'+s+'-'+title+'-'+sec_name+'.xls'


#크롬 드라이버 실행
s_time = time.time( )

path = "C:\py_temp\chromedriver_win32\chromedriver.exe" # 컴퓨터 환경에 따라 변경해야함?
driver = webdriver.Chrome(path)
    
driver.get(url)
time.sleep(5)

#자료를 수집할 카테고리 페이지로 이동
if sec == '1' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[1]/a').click( )
elif sec == '2' :                    
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[2]/a').click( )
elif sec == '3' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[3]/a').click( )
elif sec == '4' : 
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[4]/a').click( )
elif sec == '5' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[5]/a').click( )
elif sec == '6' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[6]/a').click( )
elif sec == '7' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[7]/a').click( )  
elif sec == '8' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[8]/a').click( )
elif sec == '9' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[9]/a').click( )
elif sec == '10' : 
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[10]/a').click( )
elif sec == '11' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[11]/a').click( )
elif sec == '12' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[12]/a').click( )
elif sec == '13' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[13]/a').click( )
elif sec == '14' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[14]/a').click( )
elif sec == '15' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[15]/a').click( )
elif sec == '16' : 
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[16]/a').click( )
elif sec == '17' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[17]/a').click( )
elif sec == '18' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[18]/a').click( )
elif sec == '19' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[19]/a').click( )
elif sec == '20' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[20]/a').click( )
elif sec == '21' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[21]/a').click( )
elif sec == '22' : 
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[22]/a').click( )
elif sec == '23' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[23]/a').click( )
elif sec == '24' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[24]/a').click( )
elif sec == '25' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[25]/a').click( )
elif sec == '26' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[26]/a').click( )
elif sec == '27' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[27]/a').click( )
elif sec == '28' : 
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[28]/a').click( )
elif sec == '29' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[29]/a').click( )
elif sec == '30' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[30]/a').click( )
elif sec == '31' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[31]/a').click( )
elif sec == '32' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[32]/a').click( )
elif sec == '33' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[33]/a').click( )
elif sec == '34' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[34]/a').click( )
elif sec == '35' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[35]/a').click( )
elif sec == '36' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[36]/a').click( )
elif sec == '37' : 
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[37]/a').click( )
elif sec == '38' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[38]/a').click( )
elif sec == '39' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[39]/a').click( )
elif sec == '40' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[40]/a').click( )

time.sleep(2)

#스크롤 다운
def scroll_down(driver):
      
    driver.execute_script("window.scrollBy(0,9300);")
    time.sleep(1)

scroll_down(driver)

# 이미지 추출
bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)

img_src2=[]   # 이미지 URL저장변수
file_no = 0


html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

reple_result = soup.select('#zg-center-div > #zg-ordered-list')
slist = reple_result[0].find_all('li')


#검색건수가 50이하인 경우
if cnt < 51 :
         
    ranking2=[]
    title3=[]
    price2=[]
    score2=[]
    sat_count2=[]
    store2=[]
       
    count = 0
    
    # 이미지 저장용 폴더생성
    img_dir = ft_dir+"\\images"
    os.makedirs(img_dir)
    os.chdir(img_dir)

    for li in slist:
            
            # 이미지 저장하기
            try :
                photo = li.find('div','a-section a-spacing-small').find('img')['src']
            except AttributeError :
                continue
            file_no += 1

            urllib.request.urlretrieve(photo,str(file_no)+'.jpg')
            time.sleep(1)

            if cnt == file_no :
                break
            
            f = open(ft_name, 'a',encoding='UTF-8')
            f.write("-----------------------------------------------------"+"\n")

            # 판매순위
            print("-" *70)
            try :
                ranking = li.find('span',class_='zg-badge-text').get_text().replace("#","")
            except AttributeError :
                ranking = ''
                print(ranking.replace("#",""))
            else :
                print("1.판매순위:",ranking)

                f.write('1.판매순위:'+ ranking + "\n")

            #제품 설명 
            try :
                title1 = li.find('div',class_='p13n-sc-truncated').get_text().replace("\n","")
            except AttributeError :
                title1 = ''
                print(title1.replace("\n",""))
                f.write('2.제품소개:'+ title1 + "\n")
            else :
                title2=title1.translate(bmp_map).replace("\n","") 
                print("2.제품소개:", title2.replace("\n",""))

                count += 1
             
                f.write('2.제품소개:'+ title2 + "\n")
            
             # 가격
            try :
                price = li.find('span','p13n-sc-price').get_text().replace("\n","")
            except AttributeError :
                price = ''
               
            print("3.가격:", price.replace("\n",""))
            f.write('3.가격:'+ price + "\n")
                  
            try :
                sat_count = li.find('a','a-size-small a-link-normal').get_text().replace(",","")
            except (IndexError , AttributeError) :
                sat_count='0'
                print('4.상품평 수: ',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n")
            else :
                print('4.상품평 수:',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n")

            #상품 별점 구하기
            try :
                score = li.find('span','a-icon-alt').get_text()
            except AttributeError :
                score=' '
               
            print('5.평점:',score)
            f.write('5.평점:'+ score + "\n")

            print("-" *70)
                          
            f.close( )
              
            time.sleep(0.3)
            
            ranking2.append(ranking)
            title3.append(title2.replace("\n",""))
            price2.append(price.replace("\n",""))

            try :   
                sat_count2.append(sat_count)
            except IndexError :
                sat_count2.append(0)

            score2.append(score)

            if count == cnt :
                break
                          
#검색 건수가 51건 이상인 경우
elif cnt >= 51 :    
    
    img_src2=[]   
    file_no = 0

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    count = 0

    reple_result = soup.select('#zg-center-div > #zg-ordered-list')
    slist = reple_result[0].find_all('li')


    # 이미지 내용 추출하기

    img_dir = ft_dir+"\\images"
    os.makedirs(img_dir)
    os.chdir(img_dir)

    for li in slist:

            try :
                photo = li.find('div','a-section a-spacing-small').find('img')['src']
            except AttributeError :
                continue
            file_no += 1

            urllib.request.urlretrieve(photo,str(file_no)+'.jpg')
            time.sleep(1)

            if cnt == file_no :
                break
            
    ranking2=[]
    title3=[]
    price2=[]
    score2=[]
    sat_count2=[]
    store2=[]

    for li in slist:           
            f = open(ft_name, 'a',encoding='UTF-8')
            f.write("--------------------------------------------------"+"\n")

            # 판매순위
            print("-" *70)
            try :
                ranking = li.find('span',class_='zg-badge-text').get_text().replace("#","")
            except AttributeError :
                ranking = ''
                print(ranking.replace("#",""))
            else :
                print("1.판매순위:",ranking)

                f.write('1.판매순위:'+ ranking + "\n")

            #제품 설명 
            try :
                title1 = li.find('div',class_='p13n-sc-truncated').get_text().replace("\n","")
            except AttributeError :
                title1 = ''
                print(title1.replace("\n",""))
                f.write('2.제품소개:'+ title1 + "\n")
            else :
                title2=title1.translate(bmp_map).replace("\n","") 
                print("2.제품소개:", title2.replace("\n",""))

                count += 1
             
                f.write('2.제품소개:'+ title2 + "\n")
            
             # 가격
            try :
                price = li.find('span','p13n-sc-price').get_text().replace("\n","")
            except AttributeError :
                price = ''
               
            print("3.가격:", price.replace("\n",""))
            f.write('3.가격:'+ price + "\n")
                  
            try :
                sat_count = li.find('a','a-size-small a-link-normal').get_text().replace(",","")
            except (IndexError , AttributeError) :
                sat_count='0'
                print('4.상품평 수: ',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n")
            else :
                print('4.상품평 수:',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n")

            #상품 별점 구하기
            try :
                score = li.find('span','a-icon-alt').get_text()
            except AttributeError :
                score=' '
               
                print('5.평점:',score)
                f.write('5.평점:'+ score + "\n")

                print("-" *70)
                          
                f.close( )
              
                time.sleep(0.5)

            ranking2.append(ranking)
            title3.append(title2.replace("\n",""))
            price2.append(price.replace("\n",""))

            try :   
                sat_count2.append(sat_count)
            except IndexError :
                sat_count2.append(0)

            score2.append(score)

    # 1 페이지 -> 2 페이지
    driver.find_element_by_xpath('//*[@id="zg-center-div"]/div[2]/div/ul/li[3]/a').click( )
    print("\n")
    print("잠시만 기다려 주세요~")
    print("\n")   
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    reple_result = soup.select('#zg-center-div > #zg-ordered-list')
    slist = reple_result[0].find_all('li')
    
    for li in slist:

        try :
              photo = li.find('div','a-section a-spacing-small').find('img')['src']
        except AttributeError :
              continue
        file_no += 1

        urllib.request.urlretrieve(photo,str(file_no)+'.jpg')
        time.sleep(1)

        if cnt == file_no :
              break


    for li in slist:
            
            f = open(ft_name, 'a',encoding='UTF-8')
            f.write("--------------------------------------------------"+"\n")

            # 판매순위
            print("-" *70)
            try :
                ranking = li.find('span',class_='zg-badge-text').get_text().replace("#","")
            except AttributeError :
                ranking = ''
                print(ranking.replace("#",""))
            else :
                print("1.판매순위:",ranking)

                f.write('1.판매순위:'+ ranking + "\n")

            #제품 설명 
            try :
                title1 = li.find('div',class_='p13n-sc-truncated').get_text().replace("\n","")
            except AttributeError :
                title1 = ''
                print(title1.replace("\n",""))
                f.write('2.제품소개:'+ title1 + "\n")
            else :
                title2=title1.translate(bmp_map).replace("\n","") 
                print("2.제품소개:", title2.replace("\n",""))

                count += 1
             
                f.write('2.제품소개:'+ title2 + "\n")
            
             # 가격
            try :
                price = li.find('span','p13n-sc-price').get_text().replace("\n","")
            except AttributeError :
                price = ''
               
            print("3.가격:", price.replace("\n",""))
            f.write('3.가격:'+ price + "\n")
                  
            try :
                sat_count = li.find('a','a-size-small a-link-normal').get_text().replace(",","")
            except IndexError :
                sat_count='0'
                print('4.상품평 수: ',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n")
            except AttributeError :
                sat_count='0'
                print('4.상품평 수: ',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n") 
            else :
                print('4.상품평 수:',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n")

            #상품 별점
            try :
                score = li.find('span','a-icon-alt').get_text()
            except AttributeError :
                score=' '
               
            print('5.평점:',score)
            f.write('5.평점:'+ score + "\n")

            print("-" *70)
                         
            f.close( )
              
            time.sleep(0.5)
             
            ranking2.append(ranking)
            title3.append(title2.replace("\n",""))
            price2.append(price.replace("\n",""))

            try :   
                sat_count2.append(sat_count)
            except IndexError :
                sat_count2.append(0)

            score2.append(score)
      
            if count == cnt :
                break
else :
      print(" 검색 건수는 1건 - 최대 100 건까지만 가능합니다")

        
        
amazon_best_seller = pd.DataFrame()
amazon_best_seller['판매순위']=ranking2
amazon_best_seller['제품소개']=pd.Series(title3)
amazon_best_seller['판매가격']=pd.Series(price2)
amazon_best_seller['상품평 갯수']=pd.Series(sat_count2)
amazon_best_seller['상품평점']=pd.Series(score2)


# csv 형태로 저장
amazon_best_seller.to_csv(fc_name,encoding="utf-8-sig",index=True)

# 엑셀 형태로 저장
amazon_best_seller.to_excel(fx_name ,index=True)

e_time = time.time( )
t_time = e_time - s_time

# txt 파일에 크롤링정보 저장
orig_stdout = sys.stdout
f = open(ft_name, 'a',encoding='UTF-8')
sys.stdout = f


#이미지 삽입하기

import win32com.client as win32   #win32com모듈 사용, 윈도우 환경에서 사용할 수 있다고 함,,
import win32api  

excel = win32.gencache.EnsureDispatch('Excel.Application')
wb = excel.Workbooks.Open(fx_name)
sheet = wb.ActiveSheet #엑셀 파일 열기
sheet.Columns(3).ColumnWidth = 30   #  이미지 넣을 칼럼 가로 사이즈 조정
row_cnt = cnt+1
sheet.Rows("2:%s" %row_cnt).RowHeight = 120  #  이미지 넣을 칼럼 세로 사이즈 조정

ws = wb.Sheets("Sheet1")
col_name2=[]
file_name2=[]

for a in range(2,cnt+2) :
    col_name='C'+str(a)
    col_name2.append(col_name)

for b in range(1,cnt+1) :
    file_name=img_dir+'\\'+str(b)+'.jpg'
    file_name2.append(file_name)
      
for i in range(0,cnt) :
    rng = ws.Range(col_name2[i])
    image = ws.Shapes.AddPicture(file_name2[i], False, True, rng.Left, rng.Top, 130, 100)
    excel.Visible=True
    excel.ActiveWorkbook.Save()


print("\n")
print("=" *50)
print("총 소요시간은 %s 초 이며," %t_time)
print("총 저장 건수는 %s 건 입니다 " %count)
print("=" *50)

sys.stdout = orig_stdout
f.close( )
# Out:
# ======================================================================
#     아마존 닷컴의 분야별 Best Seller 상품 정보 추출하기 + 이미지 포함
# ======================================================================
#
#
#
#     1.Amazon Devices & Accessories      2.Amazon Launchpad                3.Appliances
#     4.Apps & Games                      5.Arts, Crafts & Sewing           6.Audible Books & Originals
#     7.Automotive                        8.Baby                            9.Beauty & Personal Care
#     10.Books                            11.CDs & Vinyl                    12.Camera & Photo Products
#     13.Cell Phones & Accessories        14.Clothing, Shoes & Jewelry      15.Collectible Currencies
#     16.Computers & Accessories          17.Digital Educational Resources  18.Digital Music
#     19.Electronics                      20.Entertainment Collectibles     21.Gift Cards
#     22.Grocery & Gourmet Food           23.Handmade Products              24.Health & Household
#     25.Home & Kitchen                   26.Industrial & Scientific        27.Kindle Store
#     28.Kitchen & Dining                 29.Magazine Subscriptions         30.Movies & TV
#     31.Musical Instruments              32.Office Products                33.Patio, Lawn & Garden
#     34.Pet Supplies                     35.Software                       36.Sports & Outdoors
#     37.Sports Collectibles              38.Tools & Home Improvement       39.Toys & Games
#     40.Video Games
#
#     1.위 분야 중에서 자료를 수집할 분야의 번호를  선택하세요: 3
#     2.해당 분야에서 크롤링 할 건수는 몇건입니까?(1-100 건 사이 입력): 51
#     3.파일을 저장할 폴더명만 쓰세요(예:C:\py_temp\):C:\py_temp\
#
#
# Appliances
# 데이터 수집 중~~
# ----------------------------------------------------------------------
# 1.판매순위: 1
# 2.제품소개: Igloo ICEB26WH Automatic Portable Electric Countertop Ice Maker Machine, 9 Cubes…
# 3.가격: $109.99
# 4.상품평 수: 6076
# ----------------------------------------------------------------------
# 1.판매순위: 2
# 2.제품소개: AGLUCKY Ice Maker Machine for Countertop, Portable Ice Cube Makers, Make 26 lbs ice in…
# 3.가격: $129.99
# 4.상품평 수: 4970
# ----------------------------------------------------------------------
# 1.판매순위: 3
# 2.제품소개: Ice Maker Machine for Countertop, Self-Cleaning Function, 26Lbs/24H Portable Ice…
# 3.가격: $159.99
# 4.상품평 수: 362
# ----------------------------------------------------------------------
# 1.판매순위: 4
# 2.제품소개: GE Profile Opal | Countertop Nugget Ice Maker
# 3.가격: $549.00
# 4.상품평 수: 9038
# ----------------------------------------------------------------------
# 1.판매순위: 5
# 2.제품소개: IKICH Portable Ice Maker Machine for Countertop, Ice Cubes Ready in 6 Mins, Make…
# 3.가격: $118.99
# 4.상품평 수: 2519
# ----------------------------------------------------------------------
# 1.판매순위: 6
# 2.제품소개: Euhomy Ice Maker Machine Countertop, 26 lbs in 24 Hours, 9 Cubes Ready in 6 Mins, Electric…
# 3.가격: $95.47
# 4.상품평 수: 5762
# ----------------------------------------------------------------------
# 1.판매순위: 7
# 2.제품소개: Igloo ICEB26HNAQ Automatic Self-Cleaning Portable Electric Countertop Ice Maker…
# 3.가격: $148.59
# 4.상품평 수: 4141
# ----------------------------------------------------------------------
# 1.판매순위: 8
# 2.제품소개: Frigidaire EFIC206-Silver Compact Ice Maker, 26 lb per Day, Silver
# 3.가격: $121.73
# 4.상품평 수: 4018
# ----------------------------------------------------------------------
# 1.판매순위: 9
# 2.제품소개: Essential Values Ice Machine Cleaner 16 fl oz, Nickel Safe Descaler | Ice Maker Cleaner…
# 3.가격: $10.97
# 4.상품평 수: 1443
# ----------------------------------------------------------------------
# 1.판매순위: 10
# 2.제품소개: Broan-NuTone 412101 Non-Ducted Ductless Range Hood with Lights Exhaust Fan for…
# 3.가격: $40.23
# 4.상품평 수: 9404
# ----------------------------------------------------------------------
# 1.판매순위: 11
# 2.제품소개: CROWNFUL Ice Maker Machine for Countertop, 9 Ice Cubes Ready in 8-10 Minutes, 26lbs…
# 3.가격: $99.99
# 4.상품평 수: 5522
# ----------------------------------------------------------------------
# 1.판매순위: 12
# 2.제품소개: Automatic Self-Cleaning Ice Maker Machine for Countertop, 26lbs 24Hrs, 9 Cubes Ready in…
# 3.가격: $129.99
# 4.상품평 수: 105
# ----------------------------------------------------------------------
# 1.판매순위: 13
# 2.제품소개: Dreamiracle Ice Maker Machine for Countertop, 33 lbs Bullet Ice Cube in 24H, 9 Ice Cubes…
# 3.가격: $161.27
# 4.상품평 수: 1889
# ----------------------------------------------------------------------
# 1.판매순위: 14
# 2.제품소개: Koolatron Compact Chest Freezer with flip-up lid and 3.5 Cubic Feet Capacity - Mini…
# 3.가격: $238.69
# 4.상품평 수: 1814
# ----------------------------------------------------------------------
# 1.판매순위: 15
# 2.제품소개: Euhomy Ice Maker Machine Countertop, 40Lbs/24H Auto Self-Cleaning, 24 pcs Ice…
# 3.가격: $215.70
# 4.상품평 수: 3070
# ----------------------------------------------------------------------
# 1.판매순위: 16
# 2.제품소개: SUPER DEAL Portable Compact Mini Twin Tub Washing Machine w/Wash and Spin Cycle,…
# 3.가격: $159.89
# 4.상품평 수: 6187
# ----------------------------------------------------------------------
# 1.판매순위: 17
# 2.제품소개: Fashion Exquisite Rhinestone Hollow Out Rings Inlaid Diamond Flower Ring - Unique Creative Women Elegant Women Rings Engagement…
# 3.가격: $18.99
# 4.상품평 수:  0
# 5.평점:
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 18
# 2.제품소개: CROWNFUL Ice Maker Countertop Machine, 9 Ice Cubes Ready in 8-10 Minutes, 26lbs Bullet…
# 3.가격: $91.99
# 4.상품평 수: 2499
# ----------------------------------------------------------------------
# 1.판매순위: 19
# 2.제품소개: VIVOHOME Electric Portable Compact Countertop Automatic Ice Cube Maker…
# 3.가격: $278.01
# 4.상품평 수: 2338
# ----------------------------------------------------------------------
# 1.판매순위: 20
# 2.제품소개: Midea MRC04M3AWW Single Door Chest Freezer, 3.5 Cubic Feet, White
# 3.가격: $215.00
# 4.상품평 수: 6400
# ----------------------------------------------------------------------
# 1.판매순위: 21
# 2.제품소개: TaoTronics Nugget Ice Maker for Countertop, Sonic Ice Maker Machine, Makes 26lb Nugget…
# 3.가격: $499.99
# 4.상품평 수: 368
# ----------------------------------------------------------------------
# 1.판매순위: 22
# 2.제품소개: KINGSWERE Ice Maker Machine for Countertop, 26 lbs Bullet Ice Cube in 24H, Ice Machine with LED Display, 9 Ice Cubes Rready in 7 Mins…
# 3.가격: $109.99
# 4.상품평 수:  0
# 5.평점:
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 23
# 2.제품소개: R.W.FLAME Ice Maker Machine for Countertop，Portable Ice Cube Maker with…
# 3.가격: $129.99
# 4.상품평 수: 179
# ----------------------------------------------------------------------
# 1.판매순위: 24
# 2.제품소개: Euhomy Mini Freezer Countertop, 1.1 Cubic Feet, Single Door Compact Upright Freezer…
# 3.가격: $149.99
# 4.상품평 수: 2812
# ----------------------------------------------------------------------
# 1.판매순위: 25
# 2.제품소개: Northair 3.5 Cu Ft Chest Freezer - 2 Removable Baskets - Quiet Compact Freezer - 7…
# 3.가격: $179.99
# 4.상품평 수: 583
# ----------------------------------------------------------------------
# 1.판매순위: 26
# 2.제품소개: Igloo ICEB33BK Large-Capacity Automatic Portable Electric Countertop Ice Maker…
# 3.가격: $139.99
# 4.상품평 수: 1505
# ----------------------------------------------------------------------
# 1.판매순위: 27
# 2.제품소개: RCA RFRF450-AMZ, 5.1 Cubic Foot Chest, Deep Freezer Cold Storage for Food, White
# 3.가격: $279.99
# 4.상품평 수: 858
# ----------------------------------------------------------------------
# 1.판매순위: 28
# 2.제품소개: Kismile Counter top Ice Maker Machine with Self-Cleaning, 26LBS/24H Compact…
# 3.가격: $114.99
# 4.상품평 수: 1897
# ----------------------------------------------------------------------
# 1.판매순위: 29
# 2.제품소개: COMFEE’ 1.6 Cu.ft Portable Washing Machine, 11lbs Capacity Fully Automatic Compact…
# 3.가격: $322.93
# 4.상품평 수: 1291
# ----------------------------------------------------------------------
# 1.판매순위: 30
# 2.제품소개: Giantex Portable Mini Compact Twin Tub Washing Machine 17.6lbs Washer Spain…
# 3.가격: $199.99
# 4.상품평 수: 9373
# ----------------------------------------------------------------------
# 1.판매순위: 31
# 2.제품소개: IKICH Ice Maker Countertop, 26lbs 24Hrs, 9 Cubes Ready in 7mins, Portable Electric Ice…
# 3.가격: $104.99
# 4.상품평 수: 234
# ----------------------------------------------------------------------
# 1.판매순위: 32
# 2.제품소개: ULIT Ice Maker Countertop, Makes 26 lbs. Ice in 24 Hours,9 Ice Cubes Ready in 8 Minutes,…
# 3.가격: $119.99
# 4.상품평 수: 3031
# ----------------------------------------------------------------------
# 1.판매순위: 33
# 2.제품소개: Ice Makers Countertop, Self-Cleaning Function, Portable Electric Ice Cube Maker Machine, 9…
# 3.가격: $114.99
# 4.상품평 수: 2
# ----------------------------------------------------------------------
# 1.판매순위: 34
# 2.제품소개: Frigidaire EFRF114-AMZ Upright Freezer 1.1 cu ft Stainless Platinum Design Series
# 3.가격: $171.88
# 4.상품평 수: 344
# ----------------------------------------------------------------------
# 1.판매순위: 35
# 2.제품소개: TaoTronics TT-IC002 Countertop Machine with LCD Display, Self-Cleaning Function, 9 Bullet…
# 3.가격: $126.21
# 4.상품평 수: 956
# ----------------------------------------------------------------------
# 1.판매순위: 36
# 2.제품소개: Automatic Self Cleaning Portable Electric Countertop Ice Maker Machine With Handle,…
# 3.가격: $97.37
# 4.상품평 수: 709
# ----------------------------------------------------------------------
# 1.판매순위: 37
# 2.제품소개: Terra Hiker Ice Maker for Countertop, 9 Ice Cubes Ready in 6 Minutes, 28.7 lbs Ice in 24 Hours, No Water Line and Drain Line…
# 3.가격:
# 4.상품평 수: 532
# ----------------------------------------------------------------------
# 1.판매순위: 38
# 2.제품소개: Farberware FDW05ASBWHA Complete Portable Countertop Dishwasher with 5-Liter Built-in…
# 3.가격: $349.99
# 4.상품평 수: 1762
# ----------------------------------------------------------------------
# 1.판매순위: 39
# 2.제품소개: Counter top Ice Maker Machine with Self-cleaning- 2 Size Bullet Shaped Ice,9 Cubes…
# 3.가격: $129.99
# 4.상품평 수: 277
# ----------------------------------------------------------------------
# 1.판매순위: 40
# 2.제품소개: WATOOR Portable Ice Maker Machine for Countertop, 26 lbs Bullet Ice Cube in 24H, 9…
# 3.가격: $137.00
# 4.상품평 수: 34
# ----------------------------------------------------------------------
# 1.판매순위: 41
# 2.제품소개: NewAir Countertop Clear Ice Maker Machine, Makes 40 lbs of Ice, Portable Stainless Steel,…
# 3.가격: $248.72
# 4.상품평 수: 379
# ----------------------------------------------------------------------
# 1.판매순위: 42
# 2.제품소개: SOUKOO 2 in 1 Water Ice Maker, 48lbs Daily Ice Cube Makers,Stainless Steel Ice Makers…
# 3.가격: $269.99
# 4.상품평 수: 155
# ----------------------------------------------------------------------
# 1.판매순위: 43
# 2.제품소개: IKT Ice Maker, Counter Top Ice Making Machine with Ice Scoop and Bucket, 9 Ice Cubes Ready…
# 3.가격: $109.00
# 4.상품평 수: 110
# ----------------------------------------------------------------------
# 1.판매순위: 44
# 2.제품소개: COSTWAY Mini Washing Machine with Spin Dryer, Washing Capacity 2.5Kg, Electric…
# 3.가격: $99.99
# 4.상품평 수: 2707
# ----------------------------------------------------------------------
# 1.판매순위: 45
# 2.제품소개: 5cf Chest Freezer Deep 5 Cu Ft Compact Dorm Upright Apartment Home Food Storage…
# 3.가격: $198.00
# 4.상품평 수: 2154
# ----------------------------------------------------------------------
# 1.판매순위: 46
# 2.제품소개: COMFEE' Portable Washing Machine, 0.9 cu.ft Compact Washer With LED Display, 5 Wash…
# 3.가격: $231.97
# 4.상품평 수: 923
# ----------------------------------------------------------------------
# 1.판매순위: 47
# 2.제품소개: Cosmo 5MU30 30 in. Under Cabinet Range Hood with Ducted / Ductless Convertible…
# 3.가격: $119.95
# 4.상품평 수: 4218
# ----------------------------------------------------------------------
# 1.판매순위: 48
# 2.제품소개: The Laundry Alternative Wonderwash Retro Colors Non-electric Portable Compact Mini…
# 3.가격: $58.00
# 4.상품평 수: 417
# ----------------------------------------------------------------------
# 1.판매순위: 49
# 2.제품소개: Mini Washing Machine, 17.6 Lbs Portable Compact Washer Machine and Dryer Combo…
# 3.가격: $114.99
# 4.상품평 수: 202
# ----------------------------------------------------------------------
# 1.판매순위: 50
# 2.제품소개: SUPER DEAL Portable Compact Washing Machine, Mini Twin Tub Washing Machine w…
# 3.가격: $122.58
# 4.상품평 수: 3359
# 잠시만 기다려 주세요~
#
#
# ----------------------------------------------------------------------
# 1.판매순위: 51
# 2.제품소개: 5 cu ft Chest Freezer, Upright Single Door, Compact Space Apartment Home Food Storage Compact Saving Energy Efficient, Whiteonei
# 3.가격: $99.00
# 4.상품평 수:  0
# 5.평점:
# ----------------------------------------------------------------------
# <ipython-input-3-3d00ad55049e>:614: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   amazon_best_seller.to_excel(fx_name ,index=True)
