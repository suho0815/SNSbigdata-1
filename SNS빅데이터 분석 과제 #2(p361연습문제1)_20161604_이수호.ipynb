# %%
from bs4 import BeautifulSoup
from selenium import webdriver

import time
import sys
import re
import math
import numpy 
import pandas as pd   
import xlwt 
import random
import os
import urllib.request

print("=" *70)
print("    아마존 닷컴의 분야별 Best Seller 상품 정보 추출하기 + 이미지 포함")
print("=" *70)
print("\n")

title='아마존닷컴'
url='https://www.amazon.com/bestsellers?ld=NSGoogle'

sec = input('''
    1.Amazon Devices & Accessories      2.Amazon Launchpad                3.Appliances
    4.Apps & Games                      5.Arts, Crafts & Sewing           6.Audible Books & Originals
    7.Automotive                        8.Baby                            9.Beauty & Personal Care
    10.Books                            11.CDs & Vinyl                    12.Camera & Photo Products
    13.Cell Phones & Accessories        14.Clothing, Shoes & Jewelry      15.Collectible Currencies
    16.Computers & Accessories          17.Digital Educational Resources  18.Digital Music
    19.Electronics                      20.Entertainment Collectibles     21.Gift Cards 
    22.Grocery & Gourmet Food           23.Handmade Products              24.Health & Household
    25.Home & Kitchen                   26.Industrial & Scientific        27.Kindle Store
    28.Kitchen & Dining                 29.Magazine Subscriptions         30.Movies & TV        
    31.Musical Instruments              32.Office Products                33.Patio, Lawn & Garden               
    34.Pet Supplies                     35.Software                       36.Sports & Outdoors                   
    37.Sports Collectibles              38.Tools & Home Improvement       39.Toys & Games  
    40.Video Games

    1.위 분야 중에서 자료를 수집할 분야의 번호를  선택하세요: ''')

cnt = int(input('    2.해당 분야에서 크롤링 할 건수는 몇건입니까?(1-100 건 사이 입력): '))

f_dir = input("    3.파일을 저장할 폴더명만 쓰세요(예:C:\py_temp\):")
print("\n")

if sec == '1' :
      sec_name='Amazon Devices and Accessories'
elif sec =='2' :
      sec_name='Amazon Launchpad'
elif sec =='3' :
      sec_name='Appliances'
elif sec =='4' :
      sec_name='Apps and Games'
elif sec =='5' :
      sec_name='Arts and Crafts and Sewing'
elif sec =='6' :
      sec_name='Audible Books & Originals'        
elif sec =='7' :
      sec_name='Automotive'        
elif sec =='8' :
      sec_name='Baby'
elif sec =='9' :
      sec_name='Beauty & Personal Care'
elif sec =='10' :
      sec_name='Books'
elif sec =='11' :
      sec_name='CDs & Vinyl'
elif sec =='12' :
      sec_name='Camera & Photo Products'
elif sec =='13' :
      sec_name='Cell Phones & Accessories'
elif sec =='14' :
      sec_name='Clothing, Shoes & Jewelry'
elif sec =='15' :
      sec_name='Collectible Currencies'
elif sec =='16' :
      sec_name='Computers & Accessories'
elif sec =='17' :
      sec_name='Digital Educational Resources'
elif sec =='18' :
      sec_name='Digital Music'
elif sec =='19' :
      sec_name='Electronics'
elif sec =='20' :
      sec_name='Entertainment Collectibles'
elif sec =='21' :
      sec_name='Gift Cards'
elif sec =='22' :
      sec_name='Grocery & Gourmet Food'
elif sec =='23' :
      sec_name='Handmade Products'
elif sec =='24' :
      sec_name='Health & Household'
elif sec =='25' :
      sec_name='Home & Kitchen'
elif sec =='26' :
      sec_name='Industrial & Scientific'
elif sec =='27' :
      sec_name='Kindle Store'
elif sec =='28' :
      sec_name='Kitchen & Dining'
elif sec =='29' :
      sec_name='Magazine Subscriptions'
elif sec =='30' :
      sec_name='Movies & TV'
elif sec =='31' :
      sec_name='Musical Instruments'
elif sec =='32' :
      sec_name='Office Products'
elif sec =='33' :
      sec_name='Patio, Lawn & Garden'
elif sec =='34' :
      sec_name='Pet Supplies'
elif sec =='35' :
      sec_name='Software'
elif sec =='36' :
      sec_name='Sports & Outdoors'
elif sec =='37' :
      sec_name='Sports Collectibles'
elif sec =='38' :
      sec_name='Tools & Home Improvement'
elif sec =='39' :
      sec_name='Toys & Games'
elif sec =='40' :
      sec_name='Video Games'

        
print(sec_name)
print("데이터 수집 중~~")


#파일 이름 지정
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

os.makedirs(f_dir+s+'-'+title+'-'+sec_name)
os.chdir(f_dir+s+'-'+title+'-'+sec_name)

ft_dir=f_dir+s+'-'+title+'-'+sec_name
ft_name=f_dir+s+'-'+title+'-'+sec_name+'\\'+s+'-'+title+'-'+sec_name+'.txt'
fc_name=f_dir+s+'-'+title+'-'+sec_name+'\\'+s+'-'+title+'-'+sec_name+'.csv'
fx_name=f_dir+s+'-'+title+'-'+sec_name+'\\'+s+'-'+title+'-'+sec_name+'.xls'


#크롬 드라이버 실행
s_time = time.time( )

path = "C:\py_temp\chromedriver_win32\chromedriver.exe" # 컴퓨터 환경에 따라 변경해야함?
driver = webdriver.Chrome(path)
    
driver.get(url)
time.sleep(5)

#자료를 수집할 카테고리 페이지로 이동
if sec == '1' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[1]/a').click( )
elif sec == '2' :                    
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[2]/a').click( )
elif sec == '3' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[3]/a').click( )
elif sec == '4' : 
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[4]/a').click( )
elif sec == '5' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[5]/a').click( )
elif sec == '6' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[6]/a').click( )
elif sec == '7' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[7]/a').click( )  
elif sec == '8' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[8]/a').click( )
elif sec == '9' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[9]/a').click( )
elif sec == '10' : 
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[10]/a').click( )
elif sec == '11' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[11]/a').click( )
elif sec == '12' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[12]/a').click( )
elif sec == '13' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[13]/a').click( )
elif sec == '14' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[14]/a').click( )
elif sec == '15' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[15]/a').click( )
elif sec == '16' : 
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[16]/a').click( )
elif sec == '17' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[17]/a').click( )
elif sec == '18' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[18]/a').click( )
elif sec == '19' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[19]/a').click( )
elif sec == '20' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[20]/a').click( )
elif sec == '21' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[21]/a').click( )
elif sec == '22' : 
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[22]/a').click( )
elif sec == '23' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[23]/a').click( )
elif sec == '24' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[24]/a').click( )
elif sec == '25' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[25]/a').click( )
elif sec == '26' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[26]/a').click( )
elif sec == '27' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[27]/a').click( )
elif sec == '28' : 
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[28]/a').click( )
elif sec == '29' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[29]/a').click( )
elif sec == '30' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[30]/a').click( )
elif sec == '31' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[31]/a').click( )
elif sec == '32' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[32]/a').click( )
elif sec == '33' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[33]/a').click( )
elif sec == '34' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[34]/a').click( )
elif sec == '35' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[35]/a').click( )
elif sec == '36' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[36]/a').click( )
elif sec == '37' : 
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[37]/a').click( )
elif sec == '38' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[38]/a').click( )
elif sec == '39' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[39]/a').click( )
elif sec == '40' :
      driver.find_element_by_xpath('//*[@id="zg_browseRoot"]/ul/li[40]/a').click( )

time.sleep(2)

#스크롤 다운
def scroll_down(driver):
      
    driver.execute_script("window.scrollBy(0,9300);")
    time.sleep(1)

scroll_down(driver)

# 이미지 추출
bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)

img_src2=[]   # 이미지 URL저장변수
file_no = 0


html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

reple_result = soup.select('#zg-center-div > #zg-ordered-list')
slist = reple_result[0].find_all('li')


#검색건수가 50이하인 경우
if cnt < 51 :
         
    ranking2=[]
    title3=[]
    price2=[]
    score2=[]
    sat_count2=[]
    store2=[]
       
    count = 0
    
    # 이미지 저장용 폴더생성
    img_dir = ft_dir+"\\images"
    os.makedirs(img_dir)
    os.chdir(img_dir)

    for li in slist:
            
            # 이미지 저장하기
            try :
                photo = li.find('div','a-section a-spacing-small').find('img')['src']
            except AttributeError :
                continue
            file_no += 1

            urllib.request.urlretrieve(photo,str(file_no)+'.jpg')
            time.sleep(1)

            if cnt == file_no :
                break
            
            f = open(ft_name, 'a',encoding='UTF-8')
            f.write("-----------------------------------------------------"+"\n")

            # 판매순위
            print("-" *70)
            try :
                ranking = li.find('span',class_='zg-badge-text').get_text().replace("#","")
            except AttributeError :
                ranking = ''
                print(ranking.replace("#",""))
            else :
                print("1.판매순위:",ranking)

                f.write('1.판매순위:'+ ranking + "\n")

            #제품 설명 
            try :
                title1 = li.find('div',class_='p13n-sc-truncated').get_text().replace("\n","")
            except AttributeError :
                title1 = ''
                print(title1.replace("\n",""))
                f.write('2.제품소개:'+ title1 + "\n")
            else :
                title2=title1.translate(bmp_map).replace("\n","") 
                print("2.제품소개:", title2.replace("\n",""))

                count += 1
             
                f.write('2.제품소개:'+ title2 + "\n")
            
             # 가격
            try :
                price = li.find('span','p13n-sc-price').get_text().replace("\n","")
            except AttributeError :
                price = ''
               
            print("3.가격:", price.replace("\n",""))
            f.write('3.가격:'+ price + "\n")
                  
            try :
                sat_count = li.find('a','a-size-small a-link-normal').get_text().replace(",","")
            except (IndexError , AttributeError) :
                sat_count='0'
                print('4.상품평 수: ',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n")
            else :
                print('4.상품평 수:',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n")

            #상품 별점 구하기
            try :
                score = li.find('span','a-icon-alt').get_text()
            except AttributeError :
                score=' '
               
            print('5.평점:',score)
            f.write('5.평점:'+ score + "\n")

            print("-" *70)
                          
            f.close( )
              
            time.sleep(0.3)
            
            ranking2.append(ranking)
            title3.append(title2.replace("\n",""))
            price2.append(price.replace("\n",""))

            try :   
                sat_count2.append(sat_count)
            except IndexError :
                sat_count2.append(0)

            score2.append(score)

            if count == cnt :
                break
                          
#검색 건수가 51건 이상인 경우
elif cnt >= 51 :    
    
    img_src2=[]   
    file_no = 0

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    count = 0

    reple_result = soup.select('#zg-center-div > #zg-ordered-list')
    slist = reple_result[0].find_all('li')


    # 이미지 내용 추출하기

    img_dir = ft_dir+"\\images"
    os.makedirs(img_dir)
    os.chdir(img_dir)

    for li in slist:

            try :
                photo = li.find('div','a-section a-spacing-small').find('img')['src']
            except AttributeError :
                continue
            file_no += 1

            urllib.request.urlretrieve(photo,str(file_no)+'.jpg')
            time.sleep(1)

            if cnt == file_no :
                break
            
    ranking2=[]
    title3=[]
    price2=[]
    score2=[]
    sat_count2=[]
    store2=[]

    for li in slist:           
            f = open(ft_name, 'a',encoding='UTF-8')
            f.write("--------------------------------------------------"+"\n")

            # 판매순위
            print("-" *70)
            try :
                ranking = li.find('span',class_='zg-badge-text').get_text().replace("#","")
            except AttributeError :
                ranking = ''
                print(ranking.replace("#",""))
            else :
                print("1.판매순위:",ranking)

                f.write('1.판매순위:'+ ranking + "\n")

            #제품 설명 
            try :
                title1 = li.find('div',class_='p13n-sc-truncated').get_text().replace("\n","")
            except AttributeError :
                title1 = ''
                print(title1.replace("\n",""))
                f.write('2.제품소개:'+ title1 + "\n")
            else :
                title2=title1.translate(bmp_map).replace("\n","") 
                print("2.제품소개:", title2.replace("\n",""))

                count += 1
             
                f.write('2.제품소개:'+ title2 + "\n")
            
             # 가격
            try :
                price = li.find('span','p13n-sc-price').get_text().replace("\n","")
            except AttributeError :
                price = ''
               
                print("3.가격:", price.replace("\n",""))
                f.write('3.가격:'+ price + "\n")
                  
            try :
                sat_count = li.find('a','a-size-small a-link-normal').get_text().replace(",","")
            except (IndexError , AttributeError) :
                sat_count='0'
                print('4.상품평 수: ',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n")
            else :
                print('4.상품평 수:',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n")

            #상품 별점 구하기
            try :
                score = li.find('span','a-icon-alt').get_text()
            except AttributeError :
                score=' '
               
                print('5.평점:',score)
                f.write('5.평점:'+ score + "\n")

                print("-" *70)
                          
                f.close( )
              
                time.sleep(0.5)

                ranking2.append(ranking)
                title3.append(title2.replace("\n",""))
                price2.append(price.replace("\n",""))

            try :   
                sat_count2.append(sat_count)
            except IndexError :
                sat_count2.append(0)

                score2.append(score)

    # 1 페이지 -> 2 페이지
    driver.find_element_by_xpath('//*[@id="zg-center-div"]/div[2]/div/ul/li[3]/a').click( )
    print("\n")
    print("잠시만 기다려 주세요~")
    print("\n")   
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    reple_result = soup.select('#zg-center-div > #zg-ordered-list')
    slist = reple_result[0].find_all('li')
    
    for li in slist:

        try :
              photo = li.find('div','a-section a-spacing-small').find('img')['src']
        except AttributeError :
              continue
        file_no += 1

        urllib.request.urlretrieve(photo,str(file_no)+'.jpg')
        time.sleep(1)

        if cnt == file_no :
              break


    for li in slist:
            
            f = open(ft_name, 'a',encoding='UTF-8')
            f.write("--------------------------------------------------"+"\n")

            # 판매순위
            print("-" *70)
            try :
                ranking = li.find('span',class_='zg-badge-text').get_text().replace("#","")
            except AttributeError :
                ranking = ''
                print(ranking.replace("#",""))
            else :
                print("1.판매순위:",ranking)

                f.write('1.판매순위:'+ ranking + "\n")

            #제품 설명 
            try :
                title1 = li.find('div',class_='p13n-sc-truncated').get_text().replace("\n","")
            except AttributeError :
                title1 = ''
                print(title1.replace("\n",""))
                f.write('2.제품소개:'+ title1 + "\n")
            else :
                title2=title1.translate(bmp_map).replace("\n","") 
                print("2.제품소개:", title2.replace("\n",""))

                count += 1
             
                f.write('2.제품소개:'+ title2 + "\n")
            
             # 가격
            try :
                price = li.find('span','p13n-sc-price').get_text().replace("\n","")
            except AttributeError :
                price = ''
               
            print("3.가격:", price.replace("\n",""))
            f.write('3.가격:'+ price + "\n")
                  
            try :
                sat_count = li.find('a','a-size-small a-link-normal').get_text().replace(",","")
            except IndexError :
                sat_count='0'
                print('4.상품평 수: ',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n")
            except AttributeError :
                sat_count='0'
                print('4.상품평 수: ',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n") 
            else :
                print('4.상품평 수:',sat_count)
                f.write('4.상품평 수:'+ sat_count + "\n")

            #상품 별점
            try :
                score = li.find('span','a-icon-alt').get_text()
            except AttributeError :
                score=' '
               
            print('5.평점:',score)
            f.write('5.평점:'+ score + "\n")

            print("-" *70)
                         
            f.close( )
              
            time.sleep(0.5)
             
            ranking2.append(ranking)
            title3.append(title2.replace("\n",""))
            price2.append(price.replace("\n",""))

            try :   
                sat_count2.append(sat_count)
            except IndexError :
                sat_count2.append(0)

            score2.append(score)
      
            if count == cnt :
                break
else :
      print(" 검색 건수는 1건 - 최대 100 건까지만 가능합니다")

        
        
amazon_best_seller = pd.DataFrame()
amazon_best_seller['판매순위']=ranking2
amazon_best_seller['제품소개']=pd.Series(title3)
amazon_best_seller['판매가격']=pd.Series(price2)
amazon_best_seller['상품평 갯수']=pd.Series(sat_count2)
amazon_best_seller['상품평점']=pd.Series(score2)


# csv 형태로 저장
amazon_best_seller.to_csv(fc_name,encoding="utf-8-sig",index=True)

# 엑셀 형태로 저장
amazon_best_seller.to_excel(fx_name ,index=True)

e_time = time.time( )
t_time = e_time - s_time

# txt 파일에 크롤링정보 저장
orig_stdout = sys.stdout
f = open(ft_name, 'a',encoding='UTF-8')
sys.stdout = f


#이미지 삽입하기

import win32com.client as win32   #win32com모듈 사용, 윈도우 환경에서 사용할 수 있다고 함,,
import win32api  

excel = win32.gencache.EnsureDispatch('Excel.Application')
wb = excel.Workbooks.Open(fx_name)
sheet = wb.ActiveSheet #엑셀 파일 열기
sheet.Columns(3).ColumnWidth = 30   #  이미지 넣을 칼럼 가로 사이즈 조정
row_cnt = cnt+1
sheet.Rows("2:%s" %row_cnt).RowHeight = 120  #  이미지 넣을 칼럼 세로 사이즈 조정

ws = wb.Sheets("Sheet1")
col_name2=[]
file_name2=[]

for a in range(2,cnt+2) :
    col_name='C'+str(a)
    col_name2.append(col_name)

for b in range(1,cnt+1) :
    file_name=img_dir+'\\'+str(b)+'.jpg'
    file_name2.append(file_name)
      
for i in range(0,cnt) :
    rng = ws.Range(col_name2[i])
    image = ws.Shapes.AddPicture(file_name2[i], False, True, rng.Left, rng.Top, 130, 100)
    excel.Visible=True
    excel.ActiveWorkbook.Save()


print("\n")
print("=" *50)
print("총 소요시간은 %s 초 이며," %t_time)
print("총 저장 건수는 %s 건 입니다 " %count)
print("=" *50)

sys.stdout = orig_stdout
f.close( )
# Out:
# ======================================================================
#     아마존 닷컴의 분야별 Best Seller 상품 정보 추출하기 + 이미지 포함
# ======================================================================
#
#
#
#     1.Amazon Devices & Accessories      2.Amazon Launchpad                3.Appliances
#     4.Apps & Games                      5.Arts, Crafts & Sewing           6.Audible Books & Originals
#     7.Automotive                        8.Baby                            9.Beauty & Personal Care
#     10.Books                            11.CDs & Vinyl                    12.Camera & Photo Products
#     13.Cell Phones & Accessories        14.Clothing, Shoes & Jewelry      15.Collectible Currencies
#     16.Computers & Accessories          17.Digital Educational Resources  18.Digital Music
#     19.Electronics                      20.Entertainment Collectibles     21.Gift Cards
#     22.Grocery & Gourmet Food           23.Handmade Products              24.Health & Household
#     25.Home & Kitchen                   26.Industrial & Scientific        27.Kindle Store
#     28.Kitchen & Dining                 29.Magazine Subscriptions         30.Movies & TV
#     31.Musical Instruments              32.Office Products                33.Patio, Lawn & Garden
#     34.Pet Supplies                     35.Software                       36.Sports & Outdoors
#     37.Sports Collectibles              38.Tools & Home Improvement       39.Toys & Games
#     40.Video Games
#
#     1.위 분야 중에서 자료를 수집할 분야의 번호를  선택하세요: 5
#     2.해당 분야에서 크롤링 할 건수는 몇건입니까?(1-100 건 사이 입력): 30
#     3.파일을 저장할 폴더명만 쓰세요(예:C:\py_temp\):C:\py_temp\
#
#
# Arts and Crafts and Sewing
# 데이터 수집 중~~
# ----------------------------------------------------------------------
# 1.판매순위: 1
# 2.제품소개: Soft Tape Measure Double Scale Body Sewing Flexible Ruler for Weight Loss Medical Body…
# 3.가격: $3.99
# 4.상품평 수: 31504
# 5.평점: 4.8 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 2
# 2.제품소개: Scissors, iBayam 8" Multipurpose Scissors Bulk 3-Pack, Ultra Sharp Blade Shears, Comfort…
# 3.가격: $9.99
# 4.상품평 수: 39880
# 5.평점: 4.8 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 3
# 2.제품소개: Rit All-Purpose Liquid Dye, Apple Green
# 3.가격: $1.97
# 4.상품평 수: 27835
# 5.평점: 4.5 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 4
# 2.제품소개: Foamily Throw Pillows Set of 4-12 x 12 Premium Hypoallergenic Pillow Inserts for…
# 3.가격: $22.81
# 4.상품평 수: 38023
# 5.평점: 4.6 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 5
# 2.제품소개: HTVRONT HTV Vinyl Rolls Heat Transfer Vinyl - 12" x 8ft Red HTV Vinyl for Shirts, Iron on…
# 3.가격: $8.99
# 4.상품평 수: 6909
# 5.평점: 4.6 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 6
# 2.제품소개: Gel Pens for Adult Coloring Books, 30 Colors Gel Marker Colored Pen with 40% More Ink…
# 3.가격: $7.64
# 4.상품평 수: 18806
# 5.평점: 4.7 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 7
# 2.제품소개: iBayam Journal Planner Pens Colored Pens Fine Point Markers Fine Tip Drawing Pens Porous…
# 3.가격: $7.99
# 4.상품평 수: 57776
# 5.평점: 4.7 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 8
# 2.제품소개: HTVRONT HTV Vinyl Rolls Heat Transfer Vinyl - 12" x 20ft Apple Green HTV Vinyl for Shirts,…
# 3.가격: $15.99
# 4.상품평 수: 11574
# 5.평점: 4.7 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 9
# 2.제품소개: VELCRO Brand Industrial Fasteners Stick-On Adhesive | Professional Grade Heavy Duty…
# 3.가격: $0.01
# 4.상품평 수: 2702
# 5.평점: 4.5 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 10
# 2.제품소개: Ring Size Adjuster for Loose Rings - 12 Pack, 2 Sizes - Jewelry Sizer, Mandrel for Making…
# 3.가격: $7.99
# 4.상품평 수: 32563
# 5.평점: 4.3 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 11
# 2.제품소개: YRYM HT Clear Vinyl Transfer Paper Tape Roll-12 x 50 FT w/Alignment Grid Application…
# 3.가격: $16.99
# 4.상품평 수: 34092
# 5.평점: 4.7 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 12
# 2.제품소개: Bostitch Office HP12 3 Hole Punch, 12 Sheet Capacity, Metal,Silver
# 3.가격: $5.49
# 4.상품평 수: 27512
# 5.평점: 4.8 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 13
# 2.제품소개: Rit, Black Purpose Powder Dye, 1-1/8 oz
# 3.가격: $1.37
# 4.상품평 수: 11580
# 5.평점: 4.3 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 14
# 2.제품소개: Canson 7022446 XL Series Watercolor Textured Paper Pad for Paint 140 Pound, 11 x 15 Inch,…
# 3.가격: $7.99
# 4.상품평 수: 26925
# 5.평점: 4.8 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 15
# 2.제품소개: Super Saver Yarn, Real Teal - 1
# 3.가격: $1.51
# 4.상품평 수:  0
# 5.평점:
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 16
# 2.제품소개: BOSOBO Paint Brushes Set, 2 Pack 20 Pcs Round Pointed Tip Paintbrushes Nylon Hair…
# 3.가격: $6.99
# 4.상품평 수: 27799
# 5.평점: 4.7 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 17
# 2.제품소개: Chalktastic Liquid Chalk Markers for Blackboard Signs - Set of 18 Neon, Dry Erase…
# 3.가격: $14.99
# 4.상품평 수: 8770
# 5.평점: 4.5 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 18
# 2.제품소개: Apple Barrel Acrylic Paint in Assorted Colors (16 Ounce), 21148 Black
# 3.가격: $4.47
# 4.상품평 수: 13021
# 5.평점: 4.7 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 19
# 2.제품소개: 3 Pack PTFE Teflon Sheet for Heat Press Transfer Sheet Non Stick 16 x 20" Heat…
# 3.가격: $6.98
# 4.상품평 수: 27254
# 5.평점: 4.8 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 20
# 2.제품소개: HeatnBond Hem Iron-On Adhesive, Super Weight, 3/4 Inch x 8 Yards, Black
# 3.가격: $1.97
# 4.상품평 수: 8937
# 5.평점: 4.5 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 21
# 2.제품소개: Crayola Ultra Clean Washable Markers, Broad Line, Classic Colors, 10 Count
# 3.가격: $2.47
# 4.상품평 수: 4973
# 5.평점: 4.8 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 22
# 2.제품소개: VATIN 1-1/2" Wide Double Faced Polyester Apple Green Satin Ribbon Continuous…
# 3.가격: $10.99
# 4.상품평 수: 14812
# 5.평점: 4.8 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 23
# 2.제품소개: Exact Inkjet, Laser Print Index Paper-New
# 3.가격: $9.48
# 4.상품평 수:  0
# 5.평점:
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 24
# 2.제품소개: Tulip One-Step Tie-Dye Party, 18 Pre-Filled Bottles, Creative Group Activity, All-in-1…
# 3.가격: $17.00
# 4.상품평 수: 18439
# 5.평점: 4.8 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 25
# 2.제품소개: Elmer's All-Purpose Glue Stick, 0.21 oz, Single Stick (E511)
# 3.가격: $2.99
# 4.상품평 수: 22207
# 5.평점: 4.8 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 26
# 2.제품소개: Gorilla Dual Temp Mini Hot Glue Gun Kit with 30 Hot Glue Sticks, (Pack of 1) & Hot Glue…
# 3.가격: $12.49
# 4.상품평 수: 18087
# 5.평점: 4.7 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 27
# 2.제품소개: [Upgraded] 8 Sets Button Pins for Jeans, TOOVREN Perfect Fit Jean Button…
# 3.가격: $6.99
# 4.상품평 수: 1907
# 5.평점: 4.5 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 28
# 2.제품소개: Luna Bean Keepsake Hands Casting Kit | DIY Plaster Statue Molding Kit | Hand Holding…
# 3.가격: $39.95
# 4.상품평 수: 16800
# 5.평점: 4.6 out of 5 stars
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 29
# 2.제품소개: Soucolor Acrylic Paint Brushes Set, 20Pcs Round Pointed Tip Artist Paintbrushes for…
# 3.가격: $5.99
# 4.상품평 수: 17472
# 5.평점: 4.7 out of 5 stars
# ----------------------------------------------------------------------
# <ipython-input-2-17c1b6ed2fe7>:614: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   amazon_best_seller.to_excel(fx_name ,index=True)
# ================================================================================
# 1.요청된 총 30 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 29 건입니다
# 2.총 소요시간은 60.4 초 입니다
# 3.파일 저장 완료: txt 파일명 : C:\py_temp\2021-06-12-17-57-32-아마존닷컴-Arts and Crafts and Sewing\2021-06-12-17-57-32-아마존닷컴-Arts and Crafts and Sewing.txt
# 4.파일 저장 완료: csv 파일명 : C:\py_temp\2021-06-12-17-57-32-아마존닷컴-Arts and Crafts and Sewing\2021-06-12-17-57-32-아마존닷컴-Arts and Crafts and Sewing.csv
# 5.파일 저장 완료: xls 파일명 : C:\py_temp\2021-06-12-17-57-32-아마존닷컴-Arts and Crafts and Sewing\2021-06-12-17-57-32-아마존닷컴-Arts and Crafts and Sewing.xls
# ================================================================================
